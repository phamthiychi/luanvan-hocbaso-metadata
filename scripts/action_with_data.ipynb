# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
from dotenv import load_dotenv
import os

load_dotenv()

MONGO_DB_USERNAME = os.getenv("MONGO_DB_USERNAME")
MONGO_DB_PASSWORD = os.getenv("MONGO_DB_PASSWORD")
MONGO_DB_URI = f"mongodb+srv://{MONGO_DB_USERNAME}:{MONGO_DB_PASSWORD}@hocbaso-data.wyldsrm.mongodb.net/?appName=HocBaSo-Data"
# Create a new client and connect to the server
print(MONGO_DB_URI)
client = MongoClient(MONGO_DB_URI, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# mongodb+srv://hocbaso:ychi070501@hocbaso-data.wyldsrm.mongodb.net/?appName=HocBaSo-Data
# SSL handshake failed: ac-0v80hol-shard-00-00.wyldsrm.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1006) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-0v80hol-shard-00-01.wyldsrm.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1006) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-0v80hol-shard-00-02.wyldsrm.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1006) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 69b043204314723a05233f20, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-0v80hol-shard-00-00.wyldsrm.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-0v80hol-shard-00-00.wyldsrm.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1006) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-0v80hol-shard-00-01.wyldsrm.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-0v80hol-shard-00-01.wyldsrm.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1006) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-0v80hol-shard-00-02.wyldsrm.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-0v80hol-shard-00-02.wyldsrm.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1006) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))
from src.adapter.database.postges_manager import postgres_manager

postgres_manager.delete_db()
postgres_manager.create_db()
# Out:
# 2026-03-20 02:21:01,812 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2026-03-20 02:21:01,812 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-20 02:21:02,046 INFO sqlalchemy.engine.Engine select current_schema()
# 2026-03-20 02:21:02,053 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-20 02:21:02,286 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2026-03-20 02:21:02,286 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-20 02:21:02,519 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-03-20 02:21:02,531 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:02,531 INFO sqlalchemy.engine.Engine [generated in 0.00091s] {'table_name': 'academic_year', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:02,806 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:02,816 INFO sqlalchemy.engine.Engine [cached since 0.2838s ago] {'table_name': 'class_enrollment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:02,926 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:02,936 INFO sqlalchemy.engine.Engine [cached since 0.4068s ago] {'table_name': 'class_room', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:03,046 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:03,046 INFO sqlalchemy.engine.Engine [cached since 0.5215s ago] {'table_name': 'grade_level', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:03,187 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:03,190 INFO sqlalchemy.engine.Engine [cached since 0.6576s ago] {'table_name': 'learning_result', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:03,305 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:03,306 INFO sqlalchemy.engine.Engine [cached since 0.7746s ago] {'table_name': 'score', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:03,418 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:03,419 INFO sqlalchemy.engine.Engine [cached since 0.8875s ago] {'table_name': 'semester', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:03,536 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:03,536 INFO sqlalchemy.engine.Engine [cached since 1.013s ago] {'table_name': 'student', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:03,656 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:03,661 INFO sqlalchemy.engine.Engine [cached since 1.132s ago] {'table_name': 'subject', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:03,786 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:03,789 INFO sqlalchemy.engine.Engine [cached since 1.257s ago] {'table_name': 'teacher', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:03,927 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:03,931 INFO sqlalchemy.engine.Engine [cached since 1.399s ago] {'table_name': 'teaching_assignment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:04,046 INFO sqlalchemy.engine.Engine
# DROP TABLE teaching_assignment
# 2026-03-20 02:21:04,051 INFO sqlalchemy.engine.Engine [no key 0.00164s] {}
# 2026-03-20 02:21:04,236 INFO sqlalchemy.engine.Engine
# DROP TABLE learning_result
# 2026-03-20 02:21:04,239 INFO sqlalchemy.engine.Engine [no key 0.00417s] {}
# 2026-03-20 02:21:04,406 INFO sqlalchemy.engine.Engine
# DROP TABLE class_enrollment
# 2026-03-20 02:21:04,406 INFO sqlalchemy.engine.Engine [no key 0.00197s] {}
# 2026-03-20 02:21:04,536 INFO sqlalchemy.engine.Engine
# DROP TABLE teacher
# 2026-03-20 02:21:04,536 INFO sqlalchemy.engine.Engine [no key 0.00127s] {}
# 2026-03-20 02:21:04,656 INFO sqlalchemy.engine.Engine
# DROP TABLE subject
# 2026-03-20 02:21:04,656 INFO sqlalchemy.engine.Engine [no key 0.00193s] {}
# 2026-03-20 02:21:04,779 INFO sqlalchemy.engine.Engine
# DROP TABLE student
# 2026-03-20 02:21:04,779 INFO sqlalchemy.engine.Engine [no key 0.00168s] {}
# 2026-03-20 02:21:04,897 INFO sqlalchemy.engine.Engine
# DROP TABLE semester
# 2026-03-20 02:21:04,897 INFO sqlalchemy.engine.Engine [no key 0.00206s] {}
# 2026-03-20 02:21:05,016 INFO sqlalchemy.engine.Engine
# DROP TABLE score
# 2026-03-20 02:21:05,016 INFO sqlalchemy.engine.Engine [no key 0.00076s] {}
# 2026-03-20 02:21:05,126 INFO sqlalchemy.engine.Engine
# DROP TABLE grade_level
# 2026-03-20 02:21:05,126 INFO sqlalchemy.engine.Engine [no key 0.00263s] {}
# 2026-03-20 02:21:05,250 INFO sqlalchemy.engine.Engine
# DROP TABLE class_room
# 2026-03-20 02:21:05,250 INFO sqlalchemy.engine.Engine [no key 0.00141s] {}
# 2026-03-20 02:21:05,368 INFO sqlalchemy.engine.Engine
# DROP TABLE academic_year
# 2026-03-20 02:21:05,368 INFO sqlalchemy.engine.Engine [no key 0.00134s] {}
# 2026-03-20 02:21:05,483 INFO sqlalchemy.engine.Engine COMMIT
# All tables dropped
# 2026-03-20 02:21:05,603 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-03-20 02:21:05,608 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:05,610 INFO sqlalchemy.engine.Engine [cached since 3.079s ago] {'table_name': 'academic_year', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:05,836 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:05,836 INFO sqlalchemy.engine.Engine [cached since 3.312s ago] {'table_name': 'class_enrollment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:06,106 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:06,106 INFO sqlalchemy.engine.Engine [cached since 3.579s ago] {'table_name': 'class_room', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:06,226 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:06,231 INFO sqlalchemy.engine.Engine [cached since 3.702s ago] {'table_name': 'grade_level', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:06,366 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:06,371 INFO sqlalchemy.engine.Engine [cached since 3.839s ago] {'table_name': 'learning_result', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:06,496 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:06,501 INFO sqlalchemy.engine.Engine [cached since 3.971s ago] {'table_name': 'score', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:06,636 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:06,646 INFO sqlalchemy.engine.Engine [cached since 4.114s ago] {'table_name': 'semester', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:06,761 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:06,766 INFO sqlalchemy.engine.Engine [cached since 4.234s ago] {'table_name': 'student', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:06,886 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:06,886 INFO sqlalchemy.engine.Engine [cached since 4.358s ago] {'table_name': 'subject', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:07,001 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:07,006 INFO sqlalchemy.engine.Engine [cached since 4.476s ago] {'table_name': 'teacher', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:07,120 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-20 02:21:07,126 INFO sqlalchemy.engine.Engine [cached since 4.595s ago] {'table_name': 'teaching_assignment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-20 02:21:07,241 INFO sqlalchemy.engine.Engine
# CREATE TABLE academic_year (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	start_date DATE NOT NULL,
# 	end_date DATE NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-03-20 02:21:07,241 INFO sqlalchemy.engine.Engine [no key 0.00216s] {}
# 2026-03-20 02:21:07,856 INFO sqlalchemy.engine.Engine
# CREATE TABLE class_room (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	size INTEGER NOT NULL,
# 	special_program VARCHAR(50),
# 	PRIMARY KEY (code)
# )
#
#
# 2026-03-20 02:21:07,856 INFO sqlalchemy.engine.Engine [no key 0.00102s] {}
# 2026-03-20 02:21:08,024 INFO sqlalchemy.engine.Engine
# CREATE TABLE grade_level (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	max_students INTEGER NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-03-20 02:21:08,029 INFO sqlalchemy.engine.Engine [no key 0.00453s] {}
# 2026-03-20 02:21:08,146 INFO sqlalchemy.engine.Engine
# CREATE TABLE score (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-03-20 02:21:08,146 INFO sqlalchemy.engine.Engine [no key 0.00079s] {}
# 2026-03-20 02:21:08,266 INFO sqlalchemy.engine.Engine
# CREATE TABLE semester (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(20) NOT NULL,
# 	start_date DATE NOT NULL,
# 	end_date DATE NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-03-20 02:21:08,272 INFO sqlalchemy.engine.Engine [no key 0.00414s] {}
# 2026-03-20 02:21:08,396 INFO sqlalchemy.engine.Engine
# CREATE TABLE student (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(100) NOT NULL,
# 	card_id VARCHAR(20),
# 	edu_id VARCHAR(20),
# 	date_of_birth DATE NOT NULL,
# 	gender VARCHAR(10) NOT NULL,
# 	ethnicity VARCHAR(20) NOT NULL,
# 	status VARCHAR(30),
# 	phone VARCHAR(15),
# 	nationality VARCHAR(50) NOT NULL,
# 	address TEXT,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-03-20 02:21:08,396 INFO sqlalchemy.engine.Engine [no key 0.00073s] {}
# 2026-03-20 02:21:08,527 INFO sqlalchemy.engine.Engine
# CREATE TABLE subject (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(100) NOT NULL,
# 	total_periods INTEGER NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-03-20 02:21:08,527 INFO sqlalchemy.engine.Engine [no key 0.00227s] {}
# 2026-03-20 02:21:08,656 INFO sqlalchemy.engine.Engine
# CREATE TABLE teacher (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(100) NOT NULL,
# 	card_id VARCHAR(20),
# 	edu_id VARCHAR(20),
# 	date_of_birth DATE NOT NULL,
# 	gender VARCHAR(10) NOT NULL,
# 	ethnicity VARCHAR(20) NOT NULL,
# 	status VARCHAR(30),
# 	specialization VARCHAR(50),
# 	position VARCHAR(50),
# 	phone VARCHAR(15),
# 	nationality VARCHAR(50) NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-03-20 02:21:08,656 INFO sqlalchemy.engine.Engine [no key 0.00073s] {}
# 2026-03-20 02:21:08,775 INFO sqlalchemy.engine.Engine
# CREATE TABLE class_enrollment (
# 	student_id VARCHAR(20) NOT NULL,
# 	grade_level_id VARCHAR(20) NOT NULL,
# 	class_id VARCHAR(20) NOT NULL,
# 	academic_year_id VARCHAR(20) NOT NULL,
# 	semester_id VARCHAR(20) NOT NULL,
# 	enrollment_date DATE NOT NULL,
# 	note TEXT,
# 	PRIMARY KEY (student_id, grade_level_id, class_id, academic_year_id, semester_id),
# 	FOREIGN KEY(student_id) REFERENCES student (code),
# 	FOREIGN KEY(grade_level_id) REFERENCES grade_level (code),
# 	FOREIGN KEY(class_id) REFERENCES class_room (code),
# 	FOREIGN KEY(academic_year_id) REFERENCES academic_year (code),
# 	FOREIGN KEY(semester_id) REFERENCES semester (code)
# )
#
#
# 2026-03-20 02:21:08,780 INFO sqlalchemy.engine.Engine [no key 0.00364s] {}
# 2026-03-20 02:21:08,926 INFO sqlalchemy.engine.Engine
# CREATE TABLE learning_result (
# 	student_id VARCHAR(20) NOT NULL,
# 	class_id VARCHAR(20) NOT NULL,
# 	academic_year_id VARCHAR(20) NOT NULL,
# 	semester_id VARCHAR(20) NOT NULL,
# 	subject_id VARCHAR(20) NOT NULL,
# 	score_id VARCHAR(20) NOT NULL,
# 	score_value NUMERIC(4, 2) NOT NULL,
# 	comment VARCHAR(256),
# 	test_date DATE NOT NULL,
# 	note TEXT,
# 	PRIMARY KEY (student_id, class_id, academic_year_id, semester_id, subject_id, score_id),
# 	FOREIGN KEY(student_id) REFERENCES student (code),
# 	FOREIGN KEY(class_id) REFERENCES class_room (code),
# 	FOREIGN KEY(academic_year_id) REFERENCES academic_year (code),
# 	FOREIGN KEY(semester_id) REFERENCES semester (code),
# 	FOREIGN KEY(subject_id) REFERENCES subject (code),
# 	FOREIGN KEY(score_id) REFERENCES score (code)
# )
#
#
# 2026-03-20 02:21:08,926 INFO sqlalchemy.engine.Engine [no key 0.00290s] {}
# 2026-03-20 02:21:09,074 INFO sqlalchemy.engine.Engine
# CREATE TABLE teaching_assignment (
# 	teacher_id VARCHAR(20) NOT NULL,
# 	class_id VARCHAR(20) NOT NULL,
# 	subject_id VARCHAR(20) NOT NULL,
# 	academic_year_id VARCHAR(20) NOT NULL,
# 	semester_id VARCHAR(20) NOT NULL,
# 	role VARCHAR(30) NOT NULL,
# 	periods_per_week INTEGER NOT NULL,
# 	note TEXT,
# 	PRIMARY KEY (teacher_id, class_id, subject_id, academic_year_id, semester_id),
# 	FOREIGN KEY(teacher_id) REFERENCES teacher (code),
# 	FOREIGN KEY(class_id) REFERENCES class_room (code),
# 	FOREIGN KEY(subject_id) REFERENCES subject (code),
# 	FOREIGN KEY(academic_year_id) REFERENCES academic_year (code),
# 	FOREIGN KEY(semester_id) REFERENCES semester (code)
# )
#
#
# 2026-03-20 02:21:09,080 INFO sqlalchemy.engine.Engine [no key 0.00550s] {}
# 2026-03-20 02:21:09,206 INFO sqlalchemy.engine.Engine COMMIT
# 2026-03-20 02:21:09,320 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-03-20 02:21:09,320 INFO sqlalchemy.engine.Engine ALTER TABLE academic_year ENABLE ROW LEVEL SECURITY;
# 2026-03-20 02:21:09,320 INFO sqlalchemy.engine.Engine [generated in 0.00146s] {}
# 2026-03-20 02:21:09,551 INFO sqlalchemy.engine.Engine ALTER TABLE class_enrollment ENABLE ROW LEVEL SECURITY;
# 2026-03-20 02:21:09,556 INFO sqlalchemy.engine.Engine [generated in 0.00094s] {}
# 2026-03-20 02:21:09,676 INFO sqlalchemy.engine.Engine ALTER TABLE class_room ENABLE ROW LEVEL SECURITY;
# 2026-03-20 02:21:09,686 INFO sqlalchemy.engine.Engine [generated in 0.00349s] {}
# 2026-03-20 02:21:09,796 INFO sqlalchemy.engine.Engine ALTER TABLE grade_level ENABLE ROW LEVEL SECURITY;
# 2026-03-20 02:21:09,796 INFO sqlalchemy.engine.Engine [generated in 0.00361s] {}
# 2026-03-20 02:21:09,938 INFO sqlalchemy.engine.Engine ALTER TABLE learning_result ENABLE ROW LEVEL SECURITY;
# 2026-03-20 02:21:09,938 INFO sqlalchemy.engine.Engine [generated in 0.00148s] {}
# 2026-03-20 02:21:10,076 INFO sqlalchemy.engine.Engine ALTER TABLE score ENABLE ROW LEVEL SECURITY;
# 2026-03-20 02:21:10,088 INFO sqlalchemy.engine.Engine [generated in 0.00545s] {}
# 2026-03-20 02:21:10,238 INFO sqlalchemy.engine.Engine ALTER TABLE semester ENABLE ROW LEVEL SECURITY;
# 2026-03-20 02:21:10,241 INFO sqlalchemy.engine.Engine [generated in 0.00222s] {}
# 2026-03-20 02:21:10,356 INFO sqlalchemy.engine.Engine ALTER TABLE student ENABLE ROW LEVEL SECURITY;
# 2026-03-20 02:21:10,357 INFO sqlalchemy.engine.Engine [generated in 0.00137s] {}
# 2026-03-20 02:21:10,466 INFO sqlalchemy.engine.Engine ALTER TABLE subject ENABLE ROW LEVEL SECURITY;
# 2026-03-20 02:21:10,466 INFO sqlalchemy.engine.Engine [generated in 0.00401s] {}
# 2026-03-20 02:21:10,606 INFO sqlalchemy.engine.Engine ALTER TABLE teacher ENABLE ROW LEVEL SECURITY;
# 2026-03-20 02:21:10,616 INFO sqlalchemy.engine.Engine [generated in 0.00337s] {}
# 2026-03-20 02:21:10,736 INFO sqlalchemy.engine.Engine ALTER TABLE teaching_assignment ENABLE ROW LEVEL SECURITY;
# 2026-03-20 02:21:10,736 INFO sqlalchemy.engine.Engine [generated in 0.00131s] {}
# 2026-03-20 02:21:10,861 INFO sqlalchemy.engine.Engine COMMIT
# Tables created + RLS enabled
# Tables created

# %%
import sys
import os
from sqlalchemy import text

sys.path.append(os.path.abspath(".."))
from src.adapter.database.postges_manager import postgres_manager
postgres_manager.session.execute(text("SELECT 1"))
# Out:
# 2026-03-16 13:10:57,843 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2026-03-16 13:10:57,844 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-16 13:10:58,038 INFO sqlalchemy.engine.Engine select current_schema()
# 2026-03-16 13:10:58,043 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-16 13:10:58,234 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2026-03-16 13:10:58,236 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-16 13:10:58,424 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-03-16 13:10:58,425 INFO sqlalchemy.engine.Engine SELECT 1
# 2026-03-16 13:10:58,426 INFO sqlalchemy.engine.Engine [generated in 0.00076s] {}
