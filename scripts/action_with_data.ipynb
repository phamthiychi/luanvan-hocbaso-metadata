# %%
# from pymongo.mongo_client import MongoClient
# from pymongo.server_api import ServerApi
# from dotenv import load_dotenv
# import os

# load_dotenv()

# MONGO_DB_USERNAME = os.getenv("MONGO_DB_USERNAME")
# MONGO_DB_PASSWORD = os.getenv("MONGO_DB_PASSWORD")
# MONGO_DB_URI = f"mongodb+srv://{MONGO_DB_USERNAME}:{MONGO_DB_PASSWORD}@hocbaso-data.wyldsrm.mongodb.net/?appName=HocBaSo-Data"
# # Create a new client and connect to the server
# print(MONGO_DB_URI)
# client = MongoClient(MONGO_DB_URI, server_api=ServerApi('1'))

# # Send a ping to confirm a successful connection
# try:
#     client.admin.command('ping')
#     print("Pinged your deployment. You successfully connected to MongoDB!")
# except Exception as e:
#     print(e)

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))
from src.adapter.database.postges_manager import postgres_manager

postgres_manager.delete_db()
postgres_manager.create_db()
# Out:
# 2026-03-27 19:44:17,167 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2026-03-27 19:44:17,184 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-27 19:44:17,263 INFO sqlalchemy.engine.Engine select current_schema()
# 2026-03-27 19:44:17,265 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-27 19:44:17,333 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2026-03-27 19:44:17,333 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-03-27 19:44:17,419 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-03-27 19:44:17,430 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-27 19:44:17,432 INFO sqlalchemy.engine.Engine [generated in 0.00228s] {'table_name': 'academic_year', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-27 19:44:17,513 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-27 19:44:17,514 INFO sqlalchemy.engine.Engine [cached since 0.08402s ago] {'table_name': 'grade_level', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-27 19:44:17,551 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-27 19:44:17,551 INFO sqlalchemy.engine.Engine [cached since 0.1244s ago] {'table_name': 'class_room', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-27 19:44:17,592 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-27 19:44:17,593 INFO sqlalchemy.engine.Engine [cached since 0.1645s ago] {'table_name': 'score', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-27 19:44:17,633 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-27 19:44:17,636 INFO sqlalchemy.engine.Engine [cached since 0.2063s ago] {'table_name': 'semester', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-27 19:44:17,674 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-27 19:44:17,674 INFO sqlalchemy.engine.Engine [cached since 0.2488s ago] {'table_name': 'student', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-27 19:44:17,714 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-27 19:44:17,720 INFO sqlalchemy.engine.Engine [cached since 0.2895s ago] {'table_name': 'subject', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-27 19:44:17,758 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-27 19:44:17,760 INFO sqlalchemy.engine.Engine [cached since 0.3306s ago] {'table_name': 'teacher', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-27 19:44:17,800 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-27 19:44:17,800 INFO sqlalchemy.engine.Engine [cached since 0.3747s ago] {'table_name': 'class_enrollment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-27 19:44:17,846 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-27 19:44:17,846 INFO sqlalchemy.engine.Engine [cached since 0.4182s ago] {'table_name': 'teaching_assignment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-27 19:44:17,899 INFO sqlalchemy.engine.Engine
# DROP TABLE teaching_assignment
# 2026-03-27 19:44:17,899 INFO sqlalchemy.engine.Engine [no key 0.00419s] {}
# 2026-03-27 19:44:17,936 INFO sqlalchemy.engine.Engine
# DROP TABLE class_enrollment
# 2026-03-27 19:44:17,951 INFO sqlalchemy.engine.Engine [no key 0.00247s] {}
# 2026-03-27 19:44:17,989 INFO sqlalchemy.engine.Engine
# DROP TABLE class_room
# 2026-03-27 19:44:17,989 INFO sqlalchemy.engine.Engine [no key 0.00176s] {}
# 2026-03-27 19:44:18,033 INFO sqlalchemy.engine.Engine
# DROP TABLE teacher
# 2026-03-27 19:44:18,035 INFO sqlalchemy.engine.Engine [no key 0.00158s] {}
# 2026-03-27 19:44:18,073 INFO sqlalchemy.engine.Engine
# DROP TABLE subject
# 2026-03-27 19:44:18,073 INFO sqlalchemy.engine.Engine [no key 0.00067s] {}
# 2026-03-27 19:44:18,101 INFO sqlalchemy.engine.Engine
# DROP TABLE student
# 2026-03-27 19:44:18,116 INFO sqlalchemy.engine.Engine [no key 0.00341s] {}
# 2026-03-27 19:44:18,158 INFO sqlalchemy.engine.Engine
# DROP TABLE semester
# 2026-03-27 19:44:18,160 INFO sqlalchemy.engine.Engine [no key 0.00232s] {}
# 2026-03-27 19:44:18,205 INFO sqlalchemy.engine.Engine
# DROP TABLE score
# 2026-03-27 19:44:18,210 INFO sqlalchemy.engine.Engine [no key 0.00571s] {}
# 2026-03-27 19:44:18,251 INFO sqlalchemy.engine.Engine
# DROP TABLE grade_level
# 2026-03-27 19:44:18,253 INFO sqlalchemy.engine.Engine [no key 0.00139s] {}
# 2026-03-27 19:44:18,295 INFO sqlalchemy.engine.Engine
# DROP TABLE academic_year
# 2026-03-27 19:44:18,296 INFO sqlalchemy.engine.Engine [no key 0.00199s] {}
# 2026-03-27 19:44:18,323 INFO sqlalchemy.engine.Engine COMMIT
# All tables dropped
# 2026-03-27 19:44:18,411 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-03-27 19:44:18,426 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-27 19:44:18,426 INFO sqlalchemy.engine.Engine [cached since 0.9988s ago] {'table_name': 'academic_year', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-27 19:44:18,501 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-27 19:44:18,501 INFO sqlalchemy.engine.Engine [cached since 1.079s ago] {'table_name': 'grade_level', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-27 19:44:18,544 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-27 19:44:18,544 INFO sqlalchemy.engine.Engine [cached since 1.121s ago] {'table_name': 'class_room', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-27 19:44:18,587 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-27 19:44:18,589 INFO sqlalchemy.engine.Engine [cached since 1.159s ago] {'table_name': 'score', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-27 19:44:18,626 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-27 19:44:18,628 INFO sqlalchemy.engine.Engine [cached since 1.198s ago] {'table_name': 'semester', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-27 19:44:18,667 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-27 19:44:18,669 INFO sqlalchemy.engine.Engine [cached since 1.24s ago] {'table_name': 'student', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-27 19:44:18,712 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-27 19:44:18,714 INFO sqlalchemy.engine.Engine [cached since 1.287s ago] {'table_name': 'subject', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-27 19:44:18,756 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-27 19:44:18,757 INFO sqlalchemy.engine.Engine [cached since 1.328s ago] {'table_name': 'teacher', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-27 19:44:18,784 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-27 19:44:18,800 INFO sqlalchemy.engine.Engine [cached since 1.371s ago] {'table_name': 'class_enrollment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-27 19:44:18,840 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-03-27 19:44:18,841 INFO sqlalchemy.engine.Engine [cached since 1.411s ago] {'table_name': 'teaching_assignment', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-03-27 19:44:18,880 INFO sqlalchemy.engine.Engine
# CREATE TABLE academic_year (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	start_date DATE NOT NULL,
# 	end_date DATE NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-03-27 19:44:18,887 INFO sqlalchemy.engine.Engine [no key 0.00694s] {}
# 2026-03-27 19:44:18,932 INFO sqlalchemy.engine.Engine
# CREATE TABLE grade_level (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	max_students INTEGER NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-03-27 19:44:18,937 INFO sqlalchemy.engine.Engine [no key 0.00605s] {}
# 2026-03-27 19:44:18,978 INFO sqlalchemy.engine.Engine
# CREATE TABLE score (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-03-27 19:44:18,978 INFO sqlalchemy.engine.Engine [no key 0.00105s] {}
# 2026-03-27 19:44:19,013 INFO sqlalchemy.engine.Engine
# CREATE TABLE semester (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(20) NOT NULL,
# 	start_date DATE NOT NULL,
# 	end_date DATE NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-03-27 19:44:19,022 INFO sqlalchemy.engine.Engine [no key 0.00246s] {}
# 2026-03-27 19:44:19,068 INFO sqlalchemy.engine.Engine
# CREATE TABLE student (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(100) NOT NULL,
# 	card_id VARCHAR(20),
# 	edu_id VARCHAR(20),
# 	date_of_birth DATE NOT NULL,
# 	gender VARCHAR(10) NOT NULL,
# 	ethnicity VARCHAR(20) NOT NULL,
# 	status VARCHAR(30),
# 	phone VARCHAR(15),
# 	nationality VARCHAR(50) NOT NULL,
# 	address TEXT,
# 	father_name VARCHAR(100),
# 	father_job VARCHAR(50),
# 	father_phone VARCHAR(15),
# 	father_card_id VARCHAR(20),
# 	mother_name VARCHAR(100),
# 	mother_job VARCHAR(50),
# 	mother_phone VARCHAR(15),
# 	mother_card_id VARCHAR(20),
# 	guardian_name VARCHAR(100),
# 	guardian_job VARCHAR(50),
# 	guardian_phone VARCHAR(15),
# 	guardian_card_id VARCHAR(20),
# 	place_of_birth TEXT,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-03-27 19:44:19,071 INFO sqlalchemy.engine.Engine [no key 0.00328s] {}
# 2026-03-27 19:44:19,107 INFO sqlalchemy.engine.Engine
# CREATE TABLE subject (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(100) NOT NULL,
# 	total_periods INTEGER NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-03-27 19:44:19,119 INFO sqlalchemy.engine.Engine [no key 0.00201s] {}
# 2026-03-27 19:44:19,162 INFO sqlalchemy.engine.Engine
# CREATE TABLE teacher (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(100) NOT NULL,
# 	card_id VARCHAR(20),
# 	edu_id VARCHAR(20),
# 	date_of_birth DATE NOT NULL,
# 	gender VARCHAR(10) NOT NULL,
# 	ethnicity VARCHAR(20) NOT NULL,
# 	status VARCHAR(30),
# 	specialization VARCHAR(50),
# 	position VARCHAR(50),
# 	phone VARCHAR(15),
# 	nationality VARCHAR(50) NOT NULL,
# 	PRIMARY KEY (code)
# )
#
#
# 2026-03-27 19:44:19,164 INFO sqlalchemy.engine.Engine [no key 0.00261s] {}
# 2026-03-27 19:44:19,207 INFO sqlalchemy.engine.Engine
# CREATE TABLE class_room (
# 	code VARCHAR(20) NOT NULL,
# 	name VARCHAR(50) NOT NULL,
# 	size INTEGER NOT NULL,
# 	special_program VARCHAR(50),
# 	grade_level_code VARCHAR(20) NOT NULL,
# 	PRIMARY KEY (code),
# 	FOREIGN KEY(grade_level_code) REFERENCES grade_level (code)
# )
#
#
# 2026-03-27 19:44:19,210 INFO sqlalchemy.engine.Engine [no key 0.00247s] {}
# 2026-03-27 19:44:19,253 INFO sqlalchemy.engine.Engine
# CREATE TABLE class_enrollment (
# 	student_code VARCHAR(20) NOT NULL,
# 	class_code VARCHAR(20) NOT NULL,
# 	academic_year_code VARCHAR(20) NOT NULL,
# 	semester_code VARCHAR(20) NOT NULL,
# 	score_code VARCHAR(20) NOT NULL,
# 	subject_code VARCHAR(20) NOT NULL,
# 	enrollment_date DATE NOT NULL,
# 	note TEXT,
# 	PRIMARY KEY (student_code, class_code, academic_year_code, semester_code, score_code, subject_code),
# 	FOREIGN KEY(student_code) REFERENCES student (code),
# 	FOREIGN KEY(class_code) REFERENCES class_room (code),
# 	FOREIGN KEY(academic_year_code) REFERENCES academic_year (code),
# 	FOREIGN KEY(semester_code) REFERENCES semester (code),
# 	FOREIGN KEY(score_code) REFERENCES score (code),
# 	FOREIGN KEY(subject_code) REFERENCES subject (code)
# )
#
#
# 2026-03-27 19:44:19,257 INFO sqlalchemy.engine.Engine [no key 0.00416s] {}
# 2026-03-27 19:44:19,300 INFO sqlalchemy.engine.Engine
# CREATE TABLE teaching_assignment (
# 	teacher_code VARCHAR(20) NOT NULL,
# 	class_code VARCHAR(20) NOT NULL,
# 	subject_code VARCHAR(20) NOT NULL,
# 	role VARCHAR(30) NOT NULL,
# 	periods_per_week INTEGER NOT NULL,
# 	note TEXT,
# 	PRIMARY KEY (teacher_code, class_code, subject_code),
# 	FOREIGN KEY(teacher_code) REFERENCES teacher (code),
# 	FOREIGN KEY(class_code) REFERENCES class_room (code),
# 	FOREIGN KEY(subject_code) REFERENCES subject (code)
# )
#
#
# 2026-03-27 19:44:19,300 INFO sqlalchemy.engine.Engine [no key 0.00322s] {}
# 2026-03-27 19:44:19,354 INFO sqlalchemy.engine.Engine COMMIT
# 2026-03-27 19:44:19,393 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-03-27 19:44:19,394 INFO sqlalchemy.engine.Engine ALTER TABLE academic_year ENABLE ROW LEVEL SECURITY;
# 2026-03-27 19:44:19,396 INFO sqlalchemy.engine.Engine [generated in 0.00248s] {}
# 2026-03-27 19:44:19,472 INFO sqlalchemy.engine.Engine ALTER TABLE class_enrollment ENABLE ROW LEVEL SECURITY;
# 2026-03-27 19:44:19,472 INFO sqlalchemy.engine.Engine [generated in 0.00351s] {}
# 2026-03-27 19:44:19,507 INFO sqlalchemy.engine.Engine ALTER TABLE class_room ENABLE ROW LEVEL SECURITY;
# 2026-03-27 19:44:19,517 INFO sqlalchemy.engine.Engine [generated in 0.00221s] {}
# 2026-03-27 19:44:19,551 INFO sqlalchemy.engine.Engine ALTER TABLE grade_level ENABLE ROW LEVEL SECURITY;
# 2026-03-27 19:44:19,558 INFO sqlalchemy.engine.Engine [generated in 0.00198s] {}
# 2026-03-27 19:44:19,597 INFO sqlalchemy.engine.Engine ALTER TABLE score ENABLE ROW LEVEL SECURITY;
# 2026-03-27 19:44:19,597 INFO sqlalchemy.engine.Engine [generated in 0.00273s] {}
# 2026-03-27 19:44:19,639 INFO sqlalchemy.engine.Engine ALTER TABLE semester ENABLE ROW LEVEL SECURITY;
# 2026-03-27 19:44:19,641 INFO sqlalchemy.engine.Engine [generated in 0.00237s] {}
# 2026-03-27 19:44:19,672 INFO sqlalchemy.engine.Engine ALTER TABLE student ENABLE ROW LEVEL SECURITY;
# 2026-03-27 19:44:19,672 INFO sqlalchemy.engine.Engine [generated in 0.00318s] {}
# 2026-03-27 19:44:19,716 INFO sqlalchemy.engine.Engine ALTER TABLE subject ENABLE ROW LEVEL SECURITY;
# 2026-03-27 19:44:19,716 INFO sqlalchemy.engine.Engine [generated in 0.00137s] {}
# 2026-03-27 19:44:19,759 INFO sqlalchemy.engine.Engine ALTER TABLE teacher ENABLE ROW LEVEL SECURITY;
# 2026-03-27 19:44:19,759 INFO sqlalchemy.engine.Engine [generated in 0.00102s] {}
# 2026-03-27 19:44:19,795 INFO sqlalchemy.engine.Engine ALTER TABLE teaching_assignment ENABLE ROW LEVEL SECURITY;
# 2026-03-27 19:44:19,800 INFO sqlalchemy.engine.Engine [generated in 0.00217s] {}
# 2026-03-27 19:44:19,836 INFO sqlalchemy.engine.Engine COMMIT
# Tables created + RLS enabled
# Tables created

# %%
# import sys
# import os
# from sqlalchemy import text

# sys.path.append(os.path.abspath(".."))
# from src.adapter.database.postges_manager import postgres_manager
# postgres_manager.session.execute(text("SELECT 1"))
