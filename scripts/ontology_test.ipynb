# %%
import os
import sys
sys.path.append(os.path.abspath(".."))

from src.model.ontology.assessment import Assessment
from src.model.ontology.student import StudentReport
from src.adapter.ai.chat_gpt import ChatGptAssistant

assistant = ChatGptAssistant()
comment = "Em học tốt các môn, đặc biệt là Toán và Tiếng Việt."
assistant.extract_assessment("123.123", comment, Assessment, StudentReport)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[1], line 11
#       9 assistant = ChatGptAssistant()
#      10 comment = "Em học tốt các môn, đặc biệt là Toán và Tiếng Việt."
# ---> 11 assistant.extract_assessment("123.123", comment, Assessment, StudentReport)
#
# File d:\luanvan-hocbaso-metadata\src\adapter\ai\chat_gpt.py:31, in ChatGptAssistant.extract_assessment(self, student_code, comment, model_class, format)
#      20 def extract_assessment(self, student_code:str, comment: str,
#      21                        model_class: type, format: type) -> list:
#      22     prompt = f"""
#      23         Bạn là hệ thống AI phân tích học bạ chuyên nghiệp.
#      24         Dựa trên đoạn nhận xét sau của học sinh {student_code}: "{comment}"
#    (...)     29         Yêu cầu: Trích xuất chính xác 'evidence' từ văn bản gốc.
#      30     """
# ...
